# %% [markdown]
# ## HW 6, Part 2:   Recurrent Neural Networks (RNN)  -- Extra Credit (40 points)

# %% [markdown]
# When it comes to model sequential data such as sentences, documents and videos, etc, the state of the art approach is to use Recurrent neural network (RNN). At each timestep, RNN takes an element (such as a word) as input, combines with past information encoded as a vector (such as all information in the sentence before this timestep), generate a new vector encoding both current input and past information, then delivers it to next timestep.
#
# For more details about LSTM (a very popular variant of RNN), please refer to http://colah.github.io/posts/2015-08-Understanding-LSTMs/ and here is a very good video explaining RNN: https://www.youtube.com/watch?v=WCUNPb-5EYI.

# %% [markdown]
# ### Generating text with Long Short-Term Memory Networks
#
# RNN can be used to generate text. For more information, please read: https://karpathy.github.io/2015/05/21/rnn-effectiveness/.
#
# The following is an example script to generate text from Nietzsche's writings.
#
# Note:
# - At least 10 epochs are required before the generated text
# starts sounding coherent, but more is better.
#
# - It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# - If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
#Import necessary libraries 
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

# %%
#Get the data - available from amazon
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 600893
# total chars: 57

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 5
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Done!')
# Out:
# nb sequences: 120171
# Vectorization...
# Done!

# %% [markdown]
# Now we have data to feed a model for text generation. Next  we build a LSTM model to fit the data. Using Keras this is only few lines of code!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')
# Out:
# Build model...
# Done!

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.ma.log(preds)
    preds = preds.filled(0)
    preds = preds / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # clear_output()
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % (epoch+1))

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.4, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# # Training
# -  Each epoch takes up to 1 minute or so on a CPU (an epoch took 30 seconds for my PC)
# -  Recall that training on at least 20 epochs will give intelligible results
# -  So you're gonna have to let that puppy run for a while (if ETA per epoch is bigger than 5 minutes on your machine, you can reduce the number of epochs)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 939/939 [==============================] - ETA: 0s - loss: 2.1079
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ed with this
# one: how can the weaker par"
# ed with this
# one: how can the weaker pare and and the perither the sore the self--the realing the serper and the self-and and and the can and the portions the ore of the self-the far and sore and the self--that the sain the sore the self--the self-and and the sore and the for the self-and the sore and and the self--and the are and the for the such the conture and so the pore the sections and the and the moral the sould the serpers and s
# ----- diversity: 0.4
# ----- Generating with seed: "ed with this
# one: how can the weaker par"
# ed with this
# one: how can the weaker pare and that this serporing the for the ore and the himpereations so the all the greations and and the persent the for the somether the good the retard, and the can the man of the perparies the
# secticed the ore and here are and the self and the fare the constinct of the deess of the self--the serptions the more the can of the moral and and and the many and the suppose and and the something now of an
# ----- diversity: 0.5
# ----- Generating with seed: "ed with this
# one: how can the weaker par"
# ed with this
# one: how can the weaker pare in the perence but in our the perporing the mething the reself the are and and the farse the sore have suppanion, and the for the self the ore the german or the langing that that and so the lain which in the gen the interted the serpations and have the revilust and and have one and dears he the unterther but the preaper and and the belight the
# serponce that the seal himself the rearer and suppes
# ----- diversity: 1.0
# ----- Generating with seed: "ed with this
# one: how can the weaker par"
# ed with this
# one: how can the weaker pare, and in mepe or lave? enour itsad and some of the far de imseap
# gelose fear there sald. no discoroucs;--this is
# and the
# "impered,
# entence suppraef in
# such te
# canius and their jodequent pnocluscesets beli fe senters als ded altionss oul a self-werlical an aveny unders
# manwad him, refictes, to longaut, what for the way poorkes and recoritien in their       mey that the
# redees and as notle frew ban
# 939/939 [==============================] - 80s 85ms/step - loss: 2.1079
# Epoch 2/10
# 939/939 [==============================] - ETA: 0s - loss: 1.7016
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "equirements and similar experiences by s"
# equirements and similar experiences by such a surtion of the state and the courte and the suppestion and a station of the such a station of the such a sure a stand a such a surper the suction of the suphision and the supposition of the such a sure it is the supposing and the such a probled the such a station of the supposition of the suphision of the supposition of the state the problem also counte it is the such a station of the such a
# ----- diversity: 0.4
# ----- Generating with seed: "equirements and similar experiences by s"
# equirements and similar experiences by stand the counte indective the such the suphision of the could the highestly such problent of men of the such a stand in the suphers of the state the proble disingle to the spirit and a such a something in the sumples of a problest a spition of the probence and the such a such a such be a state and for the satifical and with it is the something the state and the fine to the believe the such as the
# ----- diversity: 0.5
# ----- Generating with seed: "equirements and similar experiences by s"
# equirements and similar experiences by such the proble subseruct and refined as his bounds a surting the something the strect possorable by the strong in the state precedilines the state imples and the occasion to subtle sonese the suppest the believe of the some the spection of an all the counte is the problems the science of the saruility and counten a talion of must fact that the object mankind as it as it is the dinger by is a stati
# ----- diversity: 1.0
# ----- Generating with seed: "equirements and similar experiences by s"
# equirements and similar experiences by spelions if which is obligice. it shame plonowled cirmly is heaver, overily occontinds ophi? all itself, the dugr-ints to prrbstint madpaitable of to deer frow mudating tor
# heast peach foe be-menxishing it the
# skeptico-a find as intermently a, to talrays, they form with which fonw was their deners morolees, in flieedenffry, whener are counted newgling to he sholaclity he a rowceps algoing
# abso ceit
# 939/939 [==============================] - 80s 85ms/step - loss: 1.7016
# Epoch 3/10
# 939/939 [==============================] - ETA: 0s - loss: 1.5778
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "ficulty being necessary.
#
# 62. to be sure"
# ficulty being necessary.
#
# 62. to be sure the presention of the conscience, and self and every sould and in the presention to the possest of the conscious and the such as its all the cases of the conscious and the man and the same of the sould and the suster in the presention of the spirituality, and a soce and the sense and sould and the suction of the conscious of the case in the conscience and and always in the self in the senses of h
# ----- diversity: 0.4
# ----- Generating with seed: "ficulty being necessary.
#
# 62. to be sure"
# ficulty being necessary.
#
# 62. to be sure of the individual to its existed and the creater, all the intellect and souls and presentioned and interple, and and all the possessions and "more and discive can believes and more such is as a conscious condicial which is as a pass of the conception to his souls and intersed that is the more and against in the cases that is to who and and inception the morality. which is as the presenting the wo
# ----- diversity: 0.5
# ----- Generating with seed: "ficulty being necessary.
#
# 62. to be sure"
# ficulty being necessary.
#
# 62. to be sure and efering the some concemning in the eacle more the morality, in body that is so long and ascord that one possess, and the presenting who be real the man from the case be as impose the case in the conception in the more of the deeling the intellect, and who in its transess, and
# belief the true and against and every
# precestly man and the can believes and dean and called in the have alsound that
# ----- diversity: 1.0
# ----- Generating with seed: "ficulty being necessary.
#
# 62. to be sure"
# ficulty being necessary.
#
# 62. to be sure of the carabitions, for wimler of the sympich and enjoy. the oblebtingly, brad "not toure
# this an lash). it espect, and anyegutian if when hud, how poist, it is
# edr or is pracwer. if to hearther, and as he stand: it is de. ha dings,  fanst"--and soca, potentant is haverned is alont, and if troe very and conmphing" and socedflest
# of claimenesvinging and discogns that
# such sympathy or as withor a b
# 939/939 [==============================] - 79s 84ms/step - loss: 1.5778
# Epoch 4/10
# 939/939 [==============================] - ETA: 0s - loss: 1.5121
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "s finger at the touch of him!
# every hand"
# s finger at the touch of him!
# every hand the same of the sense of the comparity of the properated the most disposed the sufferent of the same of the strong and the properated the sense of the same of the same of the surpose and all the properated the same of the present and strong and suffered to the same of the same of the most still of the same the contrary the truth of the conscience of the most still of the conscience of the same of
# ----- diversity: 0.4
# ----- Generating with seed: "s finger at the touch of him!
# every hand"
# s finger at the touch of him!
# every hand the same of the father the sense the most sate propering the most delicate propers the man a the instance of such the same the the man the sate passes and distrusted which heast of the conscience, and not the still of such a man from the probably more sense and are the feeling and something of the instance, and the posserible of the something and surposed the sufferent of the world itself the tru
# ----- diversity: 0.5
# ----- Generating with seed: "s finger at the touch of him!
# every hand"
# s finger at the touch of him!
# every hand the father, to the most intalled the properace of the most do a fastions and have are more and perhaps become so resulted the man also the far the possection, what strong of the feemence, what man from the command the possession he have the most desirate should suthend the disturing man that he who in surming and all the
# properly with heart errone a can ted our general to broughts, what men where
# ----- diversity: 1.0
# ----- Generating with seed: "s finger at the touch of him!
# every hand"
# s finger at the touch of him!
# every hand. the say, their passaibling--and them, our possorantal macker, from mothores. is naicnically, ited of neighglens it is to know,dqully
# and sals. the act to liet
# for perhaps say, and morality, as a,
# prescession another manners, of discepture, and not of not mhater. mure elrever from that one so claime and mactire. in
# him thous esposery,chispentading, be
# can are other of partioneds id pvolony feor i
# 939/939 [==============================] - 79s 85ms/step - loss: 1.5121
# Epoch 5/10
# 939/939 [==============================] - ETA: 0s - loss: 1.4698
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ll, it should be
# designated as the scien"
# ll, it should be
# designated as the science of the profounder the considered to the considered the same of the stronger the sensing and surpastion of the soul of the same of the propherical the same of the most as a surpomishous of the same of the same of the considered and stronger of the same of the same of the an in the conscious and as a sancess of the proples and stronger and all the sensial and and the subject is the sensing and co
# ----- diversity: 0.4
# ----- Generating with seed: "ll, it should be
# designated as the scien"
# ll, it should be
# designated as the science of the profounder and the or and spirit of the sould and stronger and its originated to self-considered
# the be the same of the subtlety and the same more strongerutes that in a come to the sensing and consides and are and has every for even which he is a maniness to the self-strengths of a commanded with the distrostive of the prother, and all the and society of the an attention of the existed
# ----- diversity: 0.5
# ----- Generating with seed: "ll, it should be
# designated as the scien"
# ll, it should be
# designated as the science of the existed a much a considered the and the greatest strong of a philosopher in a man our and a more commanded and are as a cortant superfical and and along and truths, and as a plays and a showence of the spirit it is the more the most thing sopething and conscience, and accome all the
# cossess and commantion of moral if the existent of intellige the the as a prophech, and as a could the suc
# ----- diversity: 1.0
# ----- Generating with seed: "ll, it should be
# designated as the scien"
# ll, it should be
# designated as the sciently
# igno, and strangly, the
# platuatespiness and scored,
# the lire
# hers: for the holate, enough in its under ampirative prophep of all wongh,oy hoder gratume and hithorther religious. the susedarly caray apovers of in they really
# and do ifsespitable cartance, by which every remark
# into impeoide, as even that the case of "intenditioss, to fate and still
# of his be dleimancled distrigtion of everer fal
# 939/939 [==============================] - 80s 85ms/step - loss: 1.4698
# Epoch 6/10
# 939/939 [==============================] - ETA: 0s - loss: 1.4381
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "ment (for example,
# sensual pleasure) pre"
# ment (for example,
# sensual pleasure) pressity, and and the same to the same the in the self-so the such and and the most such and all the conscious of the extent the such and souls of the same of the self-so the such and all the extent the and all the same of the same to the same of the self-saniments of the spirit of the self-sanners, and all the sense of the do the same of the self-sanned and consciousness of the such and desiration a
# ----- diversity: 0.4
# ----- Generating with seed: "ment (for example,
# sensual pleasure) pre"
# ment (for example,
# sensual pleasure) pressity of the such and and such in the world, the low to the extent that is the reso thing--and the extending that of the distances of the souls, and the and also he is the resugh and the attellition of its and also that who all the sense and states, the conscious men to be realm and contemption and all the self-nature, and the most such and the religious states and anything and there and and regar
# ----- diversity: 0.5
# ----- Generating with seed: "ment (for example,
# sensual pleasure) pre"
# ment (for example,
# sensual pleasure) pressions, in order of the pressing in the one of its and pressing into the belief and sancifferity and the refentity, the anything the most such the mestimess of the high of his man that has been and hard of the most special now and excipared and interpretation and alleres, more values to
# a self-shative and impossible and still and stand and are be and and state the conscience and prescements, and a
# ----- diversity: 1.0
# ----- Generating with seed: "ment (for example,
# sensual pleasure) pre"
# ment (for example,
# sensual pleasure) pressing
# this eace and vanye--i not and lace of impigus,
# do more contemptovation cinfut.
#
#
# h2"
#
# lather -day and
# impalis
# sai--neighto colws, as -now this fay will a still
# suphisions. an our intercalt more and intersely cart marnubaber of i the bread is at one that an habit, of langust of many which
# have rathen the indection," agombation
# cassables to
# the mensationce was the harn greatnessly how to them
# 939/939 [==============================] - 80s 85ms/step - loss: 1.4381
# Epoch 7/10
# 939/939 [==============================] - ETA: 0s - loss: 1.4130
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "s own intellect must determine for him.
# "
# s own intellect must determine for him.
#
#
# 12
#
# =artistic saints of the sense of the state of the subtlety the belief of the state of the states the more to the contented the true the hearts and the sense of the loves to the exception of the same of the strongest and standard, and some most destroparice of the sense of the subtlety the most in the strength the destruction of the state of the sense and the strift of the soulsely the strust
# ----- diversity: 0.4
# ----- Generating with seed: "s own intellect must determine for him.
# "
# s own intellect must determine for him.
#
#
# 12
#
# =the most done and experiences the development of the provalization of the same with the philosopher and the constincted and self-extions and learned and the human from the state of the most destinguish who be things a more contemptions of the or and the case and which cases of the sense and the conceptions and some the the sympathy is not were most destructable to the most discovery of the
# ----- diversity: 0.5
# ----- Generating with seed: "s own intellect must determine for him.
# "
# s own intellect must determine for him.
#
#
# 2l
# =every doubt and instinct of the most development of the strongest
# preservors, and in the forence of the forms, and more of the most from conservation, and the the internert and the promorses, and reflect of the inflicted and interitions, and many precisely and sense has conscience to the proparies of the decall of the transitality, the belief the subtlented to whom and which the feelings, th
# ----- diversity: 1.0
# ----- Generating with seed: "s own intellect must determine for him.
# "
# s own intellect must determine for him.
# -sxard, of instinct, one
# insuredic
# rogre, sepirationy, hims the
# "an here: ogrs there are dispark
# as a wholakeness, it elsed practicilus
# and
# wimines without the begor, which, no longs, the from the most in the free
# mage, nothis happiness
# but the feels, badly upon art,
# and
# however," more much and accountedays,
# andwaked, oricually as eyest what a strust ased of that becall are the
# be quediality. that
# 939/939 [==============================] - 79s 84ms/step - loss: 1.4130
# Epoch 8/10
# 938/939 [============================>.] - ETA: 0s - loss: 1.3942
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "nd the other by profession). on one occa"
# nd the other by profession). on one occase and such a soul of the subtle the strange the considere of the most such a souls of the subtle think and as the strange of the subtle present of the subsime, and the strange that the subsimes the sense of the subtle as the subtle deeple in the strong and such a socratice of the strong and strange that the subsime of the spirit of the same of the sublime in the subtle think of the soul of the su
# ----- diversity: 0.4
# ----- Generating with seed: "nd the other by profession). on one occa"
# nd the other by profession). on one occase of the subsimes man and of the constituted present of the state to experience of the sunsition of the light of the subsiment and because a sure the counted for how morality. the exception of the state the strange that it is such a spirit and socrated the considerablem of the conscience and such be the considere has been thor--the fine
# the man this man and against and provenst that there is the
# ----- diversity: 0.5
# ----- Generating with seed: "nd the other by profession). on one occa"
# nd the other by profession). on one occasion that the contination of the sure that the existence of sochated with a socratice and supposding the contempt of the really cannot lives as a sure the uniture simplation is an immediately as has been religiousness, and a manning distrusty, and such have being suppitions of desires thereby considerable and conscience of not under the extinction in the finer and desires to a sort for the saints
# ----- diversity: 1.0
# ----- Generating with seed: "nd the other by profession). on one occa"
# nd the other by profession). on one occase and tricks.--and suterian fully he encirtarile thus that is to usply begim and sustancm" for a sympathy
# and men as skeptious instinct. it experience abovt of them it searcle our cintumble advantions elewground, fow heart,--becaroc"unrables prive" classons; in nolver-be more rigrtient, ahrey a nearures.d. even, grant,
# and that
# wiman for unigenecale slee have provence must be for you gadable to c
# 939/939 [==============================] - 79s 84ms/step - loss: 1.3941
# Epoch 9/10
# 939/939 [==============================] - ETA: 0s - loss: 1.3746
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "uerian consequence, that his most convin"
# uerian consequence, that his most convinition and souls, the same disconsict, the same demons of the same singer the considered that is the same friends of the same disconsict of the same disconsict, the same simiation of the most desire the same of the same constirume of the subtle out of the conscience of the same of the same disconsictly the subtle out of the same disconsict, the same disconsict of the conscience of the same disconsi
# ----- diversity: 0.4
# ----- Generating with seed: "uerian consequence, that his most convin"
# uerian consequence, that his most convinally constirume of the most strangents of the former of the complete in an intellect of the subtle reason and problem in the same disconsict of course of a derically the recognize of the persons of the world, and out of the same disconsictly when the exciration of the same disconscions, as do the cause of the consideration and constirum of the world.=--the objective in the fact the intellectual ou
# ----- diversity: 0.5
# ----- Generating with seed: "uerian consequence, that his most convin"
# uerian consequence, that his most convinally
# conscious flights and or being facting that they have general as the will be natural and doubtly into their of which they will is destruction of the world, every constirumant problem of consideration of the consictly, which is the demourratics in the same from the sacrificed. it is not be and constinct of reprocent of
# signs of the considered the same live them is to the considered the command
# ----- diversity: 1.0
# ----- Generating with seed: "uerian consequence, that his most convin"
# uerian consequence, that his most convinition. and
# egoming been the instinct sowermenms, it is a noble fastickive christian the realnaw which if hepmost prevawec"
# discomple
# sy dreams there meds cands an inderoud feels and logical creative anothe ef the relights of things--when what levenes of their well and religious well and conveslity is
# not dame to the upon headfui the whole
# their unjure contempte. the reely filly peace"; he ceadyn w
# 939/939 [==============================] - 80s 85ms/step - loss: 1.3746
# Epoch 10/10
# 939/939 [==============================] - ETA: 0s - loss: 1.3621
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: ", hope-blessed moods has become inborn i"
# , hope-blessed moods has become inborn in the statericated the same of stalled in the each and statericate in the same with the exception of the conscience of the problem and states that is the staterically the conscience of the sense of the same with the statericated the same man of the problem of the statericated the contempt of the stateetical stalled--in the same man in the statericated the same with the statericated the conscience
# ----- diversity: 0.4
# ----- Generating with seed: ", hope-blessed moods has become inborn i"
# , hope-blessed moods has become inborn in the proule and all the independence of the other what is the same man and instincts of the man is although is the sense of the conscience of the presentive of its all the same
# time and already ree is in which is the old the contemplation and stace of the contempt of the world" of the contrary the possibication of the most stall stall from so much and presention in the same with the constius of a
# ----- diversity: 0.5
# ----- Generating with seed: ", hope-blessed moods has become inborn i"
# , hope-blessed moods has become inborn intereration of morals learn the last many we wished and at all instinct of constint in the content in every conception to be similation and colted it is the happiness, and that is not the statesice of the most individual that the the the man and the person with it be fure and individual greek
# grew asception of the superfocial conside of the world the delicate of the consequent and these for the pr
# ----- diversity: 1.0
# ----- Generating with seed: ", hope-blessed moods has become inborn i"
# , hope-blessed moods has become inborn in the alsechaps the forceful
# a fance of med, that the greater
# religionsces the cause and the very appearable himself
# we awandeness unfevence presente thiness over the all which is almost airs of a perwas faor us appass something happyss of the contrary, has
# been dadomsed." andly all deeps falours through
# a sakeess ouppose as instimet who intellect, and space
# of a comparone and saken by his shallus
# 939/939 [==============================] - 79s 85ms/step - loss: 1.3621

# %%
from numpy import *

# %% [markdown]
# ## Load pre-trained model
# Since it is time consuming to train this LSTM model with CPU for more epochs, we provided a pre-trained model which is trained on GPU for 100 epochs. Use the following code to check how coherency the model is.
#
# It requires h5py packages, please install it to test the following code.

# %%
# build the model: a single LSTM
print('Load pre-trained model...')
from keras.models import load_model
model = load_model('shakespear200.h5')


def lstm_generate(seed, model):
    orig_seed = seed
    for diversity in [0.2, 0.3, 0.5, 1.0]:
        print('----- diversity:', diversity)
        seed = orig_seed
        generated = ''
        generated += seed
        print('----- Generating with seed: "' + seed + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(seed):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            seed = seed[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


seed = "from an anguish with which no other is t"
# seed = "thou art"
lstm_generate(seed, model)
# Out:
# Load pre-trained model...
# ----- diversity: 0.2
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the subjection of the sense of the subjection of the sense of the subjection of the subjection of the subjection of the world of the subjection of the subjection of the south of the sense of the present the subjection of the sense of the capacity of the subjection of the experience of the state of the state the fact the serve the consciousness, in the state in the subjection of the subjection of th
# ----- diversity: 0.3
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the called a probably in a world of all the present in the present the present the capacity of the consequences of the subjection of the serve of the sense, and such a particularly the subjection to the concealing of the the morality and such a possible in the sense of the subjection of the superfection of the more consciousnces of the consciousness, and a present in the subjection to the conscious
# ----- diversity: 0.5
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the soul to the subjection of europe flow it such percear of him--it is the latter of the states of the subjection to the beht consequ! as a realty and the curiosity of a thing the powers of the simply the sole possible man
# and even a man, the master, and a still southtered is a men. the sense of the more yet the consciousness and seem the perceive the more heart, when
# the subjection to such a song
# ----- diversity: 1.0
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is they cannot religions of the
# plac have among their pintives,
# : their science?
# but him
# gay one may "the
# virtuates cause but, he occasially
# feigitics and he sagtem from it.
# -congline great to cusuloum of in?
#
#
# 12utquat, uspoches he taudfeclese about one
# become the things; they like precial things and home poor rome become fals oneisoced converd there even in the dseach such to diemates does alwak or

# %% [markdown]
# ### Exercise: use LSTM to generate baby names
# -  The following data set contains 8000 last names. You can download and process the name data set as follows:
#
# ```python
# name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
# with io.open(name_path, encoding='utf-8') as f:
#     text = f.read() # make it all lowercase
#
# text = text.split()
# text = ', '.join(text)
# ```
#
# Using the last name data set, answer the following tasks:
#
# - Train a LSTM to generate the names.
# - How long does it take to train? How coherent does it sound?
# - Can you train the LSTM, but for every epoch, shuffle the order of names before call model.fit()? How long does it take to train? Does it improve the coherency?

# %%
import random
name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
with io.open(name_path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 

shuffled = text.split()
text = text.split()
text = ', '.join(text)

random.shuffle(shuffled)
shuffled = ', '.join(shuffled)

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 5
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Done!')
# Out:
# nb sequences: 100350
# Vectorization...
# Done!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')
# Out:
# Build model...
# Done!

# %%
# build the model: a single LSTM
print('Build model (shuffle)...')
shuffle = Sequential()
shuffle.add(LSTM(128, input_shape=(maxlen, len(chars))))
shuffle.add(Dense(len(chars)))
shuffle.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
shuffle.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')
# Out:
# Build model (shuffle)...
# Done!

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.ma.log(preds)
    preds = preds.filled(0)
    preds = preds / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def on_epoch_end(epoch, logs):
    # clear_output()
    # Function invoked at end of each epoch. Prints generated text_temp.
    print()
    print('----- Generating text_temp after Epoch: %d' % (epoch+1))
    

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.4, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for _ in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

def on_epoch_end_shuffle(epoch, logs):
    # clear_output()
    # Function invoked at end of each epoch. Prints generated text_temp.
    print()
    print('----- Generating text_temp after Epoch: %d' % (epoch+1))
    

    start_index = random.randint(0, len(shuffled) - maxlen - 1)
    for diversity in [0.2, 0.4, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = shuffled[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for _ in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 783/784 [============================>.] - ETA: 0s - loss: 1.6659
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "enberg, schellenberger, schellenger, sch"
# enberg, schellenberger, schellenger, schlees, scheler, scheele, scheele, scheelen, scheele, scheele, scheele, scheele, scheelen, scheele, scheele, scheele, scheele, scheeler, scheele, scheele, scheelen, scheelett, scheelen, scheele, scheelen, scheeler, scheeler, scheeley, scheele, scheele, scheelen, scheelinger, scheele, scheele, scheele, scheeler, scheeley, scheele, scheelen, scheele, scheeler, scheeler, scheelen, scheeler, scheele, sc
# ----- diversity: 0.4
# ----- Generating with seed: "enberg, schellenberger, schellenger, sch"
# enberg, schellenberger, schellenger, schelling, schlees, schleis, schleis, schlein, schleine, schleit, schlein, schlein, schlein, schlein, schrein, schrein, schreile, schreile, screeling, screer, streden, streine, strein, strein, streine, streine, streine, strein, streinger, streine, streinger, streind, streine, strein, strelet, strellen, strelan, sterlen, stermant, sterman, sterman, sterman, sterman, sterman, sterman, sterman, sterman,
# ----- diversity: 0.5
# ----- Generating with seed: "enberg, schellenberger, schellenger, sch"
# enberg, schellenberger, schellenger, schelles, schleest, schlees, stlecher, steffini, steffert, steffing, steffik, steffing, steff, steffing, steffert, steffer, steffey, steffert, steffing, steffle, steffer, steffer, steffert, steffer, steffer, steffie, steffen, steffing, steffert, steffell, steffer, steffert, steffer, steffell, steffinger, steffirg, steffer, steffi, steffer, steffery, steffi, steffing, steffert, steffier, steffing, ste
# ----- diversity: 1.0
# ----- Generating with seed: "enberg, schellenberger, schellenger, sch"
# enberg, schellenberger, schellenger, schleery, swecher, schein, stweifery, steinick, steir, stiese, stieborth, stiela, stieleck, stiewman, steisce, steiler, steillan, stemen, stelesman, steetentey, steele, steeffe, stedriard, stefwi, stelff, stelf, stelarstint, stelar, stelane, stelan, stelaefto, stelfer, stelfynn, sterdvi, stetrermel, sterfey, stertin, steldy, steliber, stellinge, stelanankio, stelatzis, stelies, stelitther, steldstely
# 784/784 [==============================] - 73s 93ms/step - loss: 1.6650
# Epoch 2/10
# 783/784 [============================>.] - ETA: 0s - loss: 1.0003
# ----- Generating text_temp after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: " kramar, kramer, kramlich, kramm, kramme"
#  kramar, kramer, kramlich, kramm, krammell, kramper, krampe, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, kramper, k
# ----- diversity: 0.4
# ----- Generating with seed: " kramar, kramer, kramlich, kramm, kramme"
#  kramar, kramer, kramlich, kramm, krammer, kramman, kramman, kramman, kramman, krammer, kramper, kramper, krampes, kramper, kramper, kramper, krampe, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kraman, kr
# ----- diversity: 0.5
# ----- Generating with seed: " kramar, kramer, kramlich, kramm, kramme"
#  kramar, kramer, kramlich, kramm, krammer, krammer, kramper, kramper, kramper, kramper, krane, kraney, kranell, krane, kraner, kraner, kraney, kranie, krani, kranich, kranick, krani, kranie, kranick, kranie, kranie, kraner, krane, krane, kranell, kraner, kraner, kranera, kraner, kraner, kraner, kranell, krane, kraner, kranich, kranicht, kranich, kraninger, kranie, kranike, kraning, kraniti, krani, kran, kranch, kranf, krane, kranch, kra
# ----- diversity: 1.0
# ----- Generating with seed: " kramar, kramer, kramlich, kramm, kramme"
#  kramar, kramer, kramlich, kramm, krammey, kram, kramell, kroen, kreoncith, kreordan, krererf, krerifer, krerilworf, kreris, krerice, krericch, krerilie, krerise, krerika, kreirner, kreirick, kreisching, kreisten, kreithi, kreigh, kreiduin, kreid, kreiech, kreite, keriat, kerha, kerh, kerham, keril, kerley, kerline, kerick, keirrich, keiria, keirsk, keish, kies, kiescan, kies, kiessa, kiesta, kiesh, kiesa, kiess, kieshur, kisett, kistem
# 784/784 [==============================] - 74s 95ms/step - loss: 1.0002
# Epoch 3/10
# 783/784 [============================>.] - ETA: 0s - loss: 0.8992
# ----- Generating text_temp after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: ", cosmo, cosner, cosola, cosper, coss, c"
# , cosmo, cosner, cosola, cosper, coss, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cossel, cosser, cossett, cossett, cossett, cossett, cossett, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, coss
# ----- diversity: 0.4
# ----- Generating with seed: ", cosmo, cosner, cosola, cosper, coss, c"
# , cosmo, cosner, cosola, cosper, coss, coss, cosse, cossel, cossen, cosser, cossenberg, cossert, cossett, cossett, cossett, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cossson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cos
# ----- diversity: 0.5
# ----- Generating with seed: ", cosmo, cosner, cosola, cosper, coss, c"
# , cosmo, cosner, cosola, cosper, coss, cossett, cosson, cosson, cossett, cosson, cosson, cosson, cosson, cosson, cosson, cossentin, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, coss, cossbian, cossenton, cossett, cossett, cossing, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson, cosson
# ----- diversity: 1.0
# ----- Generating with seed: ", cosmo, cosner, cosola, cosper, coss, c"
# , cosmo, cosner, cosola, cosper, coss, cossenmon, cost, costats, costel, costick, costley, coston, costrelki, cost, costerston, cotrey, cotts, cotzek, coffelm, cofey, coffinger, cofforsh, cfoghert, coggs, coggort, cogt, cogtens, cogtschine, cogtscourn, cogter, cogush, cogur, cogue, cogu, coguhar, covinnette, covsyn, covonby, covolbe, covolan, covona, covona, covoletta, covoni, covorthox, covar, coverter, covittes, covito, covirowellpee,
# 784/784 [==============================] - 74s 95ms/step - loss: 0.8993
# Epoch 4/10
# 784/784 [==============================] - ETA: 0s - loss: 0.8387
# ----- Generating text_temp after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "ves, stavinoha, stavola, stavropoulos, s"
# ves, stavinoha, stavola, stavropoulos, stavrick, stavinger, stavinger, stavinski, staving, staving, staving, stavinger, stavinski, stavinski, stavinski, stavinski, stavinski, stavinski, stavinski, stavinski, stavinski, stavis, stavitt, stavitt, stavitt, stavitt, stavitt, stavitt, stavitt, stavitt, stavick, stavick, stavick, stavick, stavick, stavick, stavick, stavick, stavick, stavick, stavick, stavick, stavick, stavick, stavick, stavic
# ----- diversity: 0.4
# ----- Generating with seed: "ves, stavinoha, stavola, stavropoulos, s"
# ves, stavinoha, stavola, stavropoulos, stavringer, stavitt, stavitta, stavico, stavico, stavic, stavico, stavick, stavick, stavick, stavickson, stavickson, stavick, stavick, stavick, stavick, stavick, stavickski, stavitz, stavick, stavick, stavick, stavick, stavie, stavin, staving, stavinger, stavinski, stavinski, staw, stawall, stawand, stawand, stawberg, staway, staward, staward, stawand, stawan, stawant, stawand, staward, staward, st
# ----- diversity: 0.5
# ----- Generating with seed: "ves, stavinoha, stavola, stavropoulos, s"
# ves, stavinoha, stavola, stavropoulos, stavrey, stavy, stavalling, stavich, stavick, stavice, stavita, stavitt, stavitte, stavis, stavitt, stavick, stavilla, stavinger, stavinski, stavinski, stavinger, stavinski, stavinski, staw, staw, staward, stawn, stawn, stawner, stawn, stawns, swayter, swayt, swayter, swayter, sway, swayler, swayter, swayter, swayter, swayton, swayt, swayt, swayl, swayl, swayer, sway, swayles, swayter, sway, swayne
# ----- diversity: 1.0
# ----- Generating with seed: "ves, stavinoha, stavola, stavropoulos, s"
# ves, stavinoha, stavola, stavropoulos, stavly, staw, stavebai, statzie, stavie, stawley, staveyer, stavin, stavingham, stantona, stantox, stanzamar, staxnis, statyne, statzman, statt, statts, statzir, staviceetse, stavex, stavenson, stavin, stavine, stauma, stivaugh, sthives, stiwoal, stiwella, stiwallo, stigvott, sti, sticano, stiban, sticber, stick, stidbee, stidea, stidella, stidel, stidie, stidley, stidletlio, spiwakt, spiwko, spido
# 784/784 [==============================] - 74s 94ms/step - loss: 0.8387
# Epoch 5/10
# 783/784 [============================>.] - ETA: 0s - loss: 0.7970
# ----- Generating text_temp after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: " vadney, vaeth, vahe, vahey, vahid, vahl"
#  vadney, vaeth, vahe, vahey, vahid, vahl, vahle, vahler, wahler, wahler, wahler, wahler, wahler, wahler, wahler, wahler, wahler, wahler, wahler, wahler, wahler, wahling, wahling, wahling, wahling, wahlinger, wahling, wahling, wahling, wahling, wahling, wahling, wahling, wahling, wahling, wahling, wahling, wahling, wahling, wahlinger, wahling, wahling, wahling, wahlinger, wahling, wahling, wahling, wahling, wahlinger, wahling, wahling, w
# ----- diversity: 0.4
# ----- Generating with seed: " vadney, vaeth, vahe, vahey, vahid, vahl"
#  vadney, vaeth, vahe, vahey, vahid, vahle, vahler, wahler, wahler, wahler, wahler, wahl, wahle, wahler, wahler, wahling, wahling, wahling, wahlington, wahling, wahlington, wahling, wahnhorn, wahring, wahr, wahrer, wahrer, wahr, wahrer, wahr, wahrer, wahrett, wahr, wahr, wahre, wahrer, wahr, wahr, wahr, wahrer, wahr, wahr, wahr, wahran, wahr, wahr, wahr, wahrer, wahrer, wahr, wahrer, wahr, wahrer, wahrer, wahr, wahrer, wahrer, wahr, wahr
# ----- diversity: 0.5
# ----- Generating with seed: " vadney, vaeth, vahe, vahey, vahid, vahl"
#  vadney, vaeth, vahe, vahey, vahid, vahler, vahley, vahller, vahling, vahlinger, vahlinff, wailer, vailler, vaimell, vaimer, vaimer, vaimers, vairo, vair, vaire, vaire, vairer, vairig, vairing, vairing, vairing, vairing, vairinger, vairi, vairie, vairi, vairis, vairie, vairig, vairle, vairella, vairelle, vairelsti, vairelli, varier, variff, varie, variger, varigore, varillo, varine, varine, varine, varine, varing, varinger, varing, vari
# ----- diversity: 1.0
# ----- Generating with seed: " vadney, vaeth, vahe, vahey, vahid, vahl"
#  vadney, vaeth, vahe, vahey, vahid, vahl, vahlhami, wahiling, wahley, wahlinger, wahlt, wahrley, wahrkowsky, wahrer, waric, warick, waritz, warin, warind, waringes, warn, warne, warnent, warnill, warkolp, warlings, warnick, warningey, warno, warnwond, warnwell, warwell, warryls, wary, wargronstih, wargwoen, waring, warin, warini, warjinger, warmeker, warn, warne, warnikow, warnort, warnfie, warney, warney, warny, wanwie, wanzyn, wanzer,
# 784/784 [==============================] - 74s 94ms/step - loss: 0.7967
# Epoch 6/10
# 783/784 [============================>.] - ETA: 0s - loss: 0.7632
# ----- Generating text_temp after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "ettler, kettles, kettlewell, kettner, ke"
# ettler, kettles, kettlewell, kettner, kettner, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketton, ketts, ketty, ketzer, ketzen, ketzel, ketzel, ketzel, ketzel, ketzel, ketzel, ketzel, ketzel, ketzer, ketzel, ketzel, ketzel, ketzel, ketzel, ketzel, ketzel, ketzel, ketzel, ketzer, ketzel, ketzel, ketzel, ketzer, ket
# ----- diversity: 0.4
# ----- Generating with seed: "ettler, kettles, kettlewell, kettner, ke"
# ettler, kettles, kettlewell, kettner, ketton, kettman, kettner, ketton, ketts, kettzel, ketzer, ketzer, ketzel, ketzel, ketzel, ketzel, ketzel, ketzel, ketzen, ketz, ketzer, ketzer, ketzer, ketzel, ketzel, ketzel, ketzel, ketzel, ketzer, ketzel, ketzer, ketzel, ketzen, ketzen, ketzen, ketzel, ketzel, ketzer, ketzel, ketzel, ketzel, ketzel, ketzer, ketzer, ketzman, ketzon, ketzen, ketzel, ketzer, ketzke, ketzmen, ketzel, ketzen, ketzen,
# ----- diversity: 0.5
# ----- Generating with seed: "ettler, kettles, kettlewell, kettner, ke"
# ettler, kettles, kettlewell, kettner, kettner, kettner, ketton, kettmeier, kettmer, kettold, kettman, kettmann, ketton, ketton, ketts, ketty, ketzer, ketzen, ketzel, ketzel, ketzen, ketzel, ketzer, ketzo, ketzman, ketzel, ketzel, ketzel, ketzel, ketzon, ketzen, ketzo, ketzel, ketzar, ketzhue, ketzman, ketzman, ketzel, ketzel, ketzee, ketzel, ketzer, ketzer, ketzer, ketzel, ketzel, ketzen, ketzman, ketzel, ketzer, ketzon, ketzon, ketzon,
# ----- diversity: 1.0
# ----- Generating with seed: "ettler, kettles, kettlewell, kettner, ke"
# ettler, kettles, kettlewell, kettner, kettock, ketuini, kety, ketzen, ketzen, ketzke, ketzner, ketzman, ketzel, ketzark, ketzelen, ketzinde, ketz, ketzer, ketzler, ketchnell, ketes, ketcht, ketey, kebrignt, kebrie, kebland, kebkl, kebing, keadine, keal, keadley, keaa, keapert, keapp, keas, keasar, keasar, kease, keasley, keatle, keatlea, keattle, keaurich, keary, keat, keather, keathauer, keathers, keather, keatley, keatlund, keethman,
# 784/784 [==============================] - 76s 97ms/step - loss: 0.7628
# Epoch 7/10
# 783/784 [============================>.] - ETA: 0s - loss: 0.7330
# ----- Generating text_temp after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: " scaturro, scavo, scavone, scavuzzo, sce"
#  scaturro, scavo, scavone, scavuzzo, scevarino, scevario, scevario, scevario, scevario, scevario, scevario, scevario, scevario, scevario, scevario, scevario, scevarino, scevara, scevarino, scevario, scevario, scevario, scevario, scevario, scevarino, scevario, scevario, scevario, scevario, scevario, scevarini, scevario, scevario, scevario, scevario, scevario, scevarino, scevario, scevario, scevario, scevario, scevario, scevario, scevarin
# ----- diversity: 0.4
# ----- Generating with seed: " scaturro, scavo, scavone, scavuzzo, sce"
#  scaturro, scavo, scavone, scavuzzo, sceusta, scul, scull, scull, scull, scullor, scullo, scullo, scullowski, scullo, scullo, sculla, sculla, sculla, scullo, scullor, scullara, scullo, scullo, scullo, scullo, scullo, scullo, scullora, sculla, sculla, scullia, scullor, scullo, sculla, scullo, scullor, scullo, scul, scull, scullard, scull, scull, sculli, scullo, scullo, scullo, scullo, scullor, scullor, scullo, sculla, scullor, scullor, s
# ----- diversity: 0.5
# ----- Generating with seed: " scaturro, scavo, scavone, scavuzzo, sce"
#  scaturro, scavo, scavone, scavuzzo, sceul, scullo, scullor, scullo, sculla, scullo, scullor, scula, sculca, sculbrie, sculci, sculco, sculco, sculco, stucilia, scus, stucillo, stuculla, stucitti, stucista, stucita, stucita, stucita, stucti, stucita, stucis, stuco, stuculli, stuculli, stucota, stucis, stucca, stucista, stucisi, stuciur, stucis, stucista, stucise, stucit, stucista, stucis, stucita, stucis, stuciss, stucista, stucissi, st
# ----- diversity: 1.0
# ----- Generating with seed: " scaturro, scavo, scavone, scavuzzo, sce"
#  scaturro, scavo, scavone, scavuzzo, sceveu, sci, sciara, sciario, scicagroderto, scichi, scichoraulo, scicko, sciprell, scipralca, sciscorlia, sciptle, sciprico, scir, scisdiaa, sciscilro, scipainto, scis, scisenrac, sciskowski, scithorell, scipios, sciorelo, scis, scisco, scise, scisco, sciscolo, sciskor, sciro, stioria, stiss, stissler, stitt, stitzer, stimter, stimsett, stimmen, stimmo, stimmo, stimmmer, stimmong, stimos, stimp, sti
# 784/784 [==============================] - 78s 100ms/step - loss: 0.7333
# Epoch 8/10
# 784/784 [==============================] - ETA: 0s - loss: 0.7058
# ----- Generating text_temp after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "eatherington, weatherly, weatherman, wea"
# eatherington, weatherly, weatherman, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather
# ----- diversity: 0.4
# ----- Generating with seed: "eatherington, weatherly, weatherman, wea"
# eatherington, weatherly, weatherman, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weater, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather,
# ----- diversity: 0.5
# ----- Generating with seed: "eatherington, weatherly, weatherman, wea"
# eatherington, weatherly, weatherman, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weather, weath, weather, weather, weather, weather, weather, weather, weather, weather, weatinger, weatler, weatler, weater, weater, weater, weather, weather, weath, weather, weather, weather, weather, weather, wea
# ----- diversity: 1.0
# ----- Generating with seed: "eatherington, weatherly, weatherman, wea"
# eatherington, weatherly, weatherman, weatherman, weather, weatinga, weatlee, weathel, weatkler, weatie, weagle, wean, wean, weandstein, weadne, weadon, weale, weaney, weandy, weadner, weaene, weangham, weagle, weagnel, weaglo, weaglan, weaghow, weagenberg, weagen, weager, weadeys, weag, weaklassee, weadley, weadley, weadles, weadar, weadey, weadinger, weackman, wead, weadje, weaepian, weady, weadra, weadre, weadlo, weady, weae, weagen,
# 784/784 [==============================] - 78s 100ms/step - loss: 0.7058
# Epoch 9/10
# 784/784 [==============================] - ETA: 0s - loss: 0.6842
# ----- Generating text_temp after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "und, braune, brauner, brauns, braunschwe"
# und, braune, brauner, brauns, braunschweit, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, brauns, bravo, bravill, bravill, bravilli, bravilli, bravilli, bravilli, bravilli, bravilli, bravilli, bravilli, bravilli, bravilli, bravilli, bravilli, bravilli, b
# ----- diversity: 0.4
# ----- Generating with seed: "und, braune, brauner, brauns, braunschwe"
# und, braune, brauner, brauns, braunschweid, braums, braums, braum, brauman, brauman, brauman, braumann, brauman, brauman, brauman, brauman, braumann, brauman, brauman, brauman, brauman, brauman, brauman, brauna, brauna, brauna, brauna, brauna, brauna, brauna, braunch, braunch, braune, brauner, brauner, bravo, bravaly, bravalet, bravelita, bravie, bravie, bravilla, bravillini, bravilli, bravillin, bravillio, bravilia, bravilli, bravillis
# ----- diversity: 0.5
# ----- Generating with seed: "und, braune, brauner, brauns, braunschwe"
# und, braune, brauner, brauns, braunschweit, braunss, braun, brauna, braun, brauna, brauna, brauna, brauna, bravo, bravella, bravelli, bravellie, bravil, bravill, bravillis, bravillio, bravilla, bravilli, bravilli, bravilli, bravilli, bravillia, bravilli, bravilline, bravillis, bravillo, bravill, bravilli, bravilli, bravilla, bravillie, bravilli, bravilli, bravilli, bravilli, bravillis, bravilli, bravilli, bravillo, bravilli, bravillo, b
# ----- diversity: 1.0
# ----- Generating with seed: "und, braune, brauner, brauns, braunschwe"
# und, braune, brauner, brauns, braunschweid, braumson, braum, brauman, brauna, brauna, braunce, bravrar, brava, bravack, brave, brabughta, bravick, braw, brawan, brawe, brawer, brawle, brawles, brawlis, brawles, brawlety, braws, braw, bray, braye, brayla, braz, brazar, bravel, bravill, bravese, braw, brawardt, brawad, brawad, braweber, brawers, brawies, brawhon, brawhman, brawhaitre, brawie, brailla, braon, branner, brann, branongey, bra
# 784/784 [==============================] - 78s 100ms/step - loss: 0.6842
# Epoch 10/10
# 783/784 [============================>.] - ETA: 0s - loss: 0.6634
# ----- Generating text_temp after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "troy, monts, montuori, montville, monty,"
# troy, monts, montuori, montville, monty, monty, monz, monz, monzer, mozza, mozza, mozzara, mozzo, mozzo, mozzo, mozza, mozzo, mozzo, mozza, mczak, mczar, mczar, mzarda, murand, murcant, murcant, murcar, murcara, murcara, murcarano, murcarini, murcaro, murcaro, murcaro, murcarano, murcarini, murcarini, murcarini, murcarini, murcaro, murcarine, murcaro, murcaro, murcarini, murcarini, murcarini, murcarano, murcarini, murcarini, murcarini,
# ----- diversity: 0.4
# ----- Generating with seed: "troy, monts, montuori, montville, monty,"
# troy, monts, montuori, montville, monty, monz, monzer, monzer, mozza, mozza, mozzan, mozzan, mozzo, mozzo, mozzo, mozzo, mozzon, mczar, mczar, mczar, mczar, mczar, mczar, mazel, mazebrand, mazeau, mazeal, mazeal, mazeal, mazeal, mazeak, mazeal, mazeal, mazear, mazebarg, mazeau, mazeak, mazeal, mazeberg, mazeberg, mazeburg, mazebarg, mazebrak, mazella, mazella, mazello, mazella, mazella, mazella, mazella, mazella, mazella, mazella, mazel
# ----- diversity: 0.5
# ----- Generating with seed: "troy, monts, montuori, montville, monty,"
# troy, monts, montuori, montville, monty, monty, monz, monz, monzer, mozza, mozza, mozzon, mozzon, mozzo, mozzo, mozzyn, mozzyn, mozzon, mozzo, mozzo, mcoz, mczak, mczar, mczar, mzabre, mabynson, macar, maccant, maccarelli, maccaro, maccaro, maccardia, maccaros, macchiona, macchursti, macchury, macdica, macdick, macdill, macdill, maddin, maddin, maddin, maddy, maddon, maddon, madding, maddy, mader, mado, madoli, madoline, madon, madona,
# ----- diversity: 1.0
# ----- Generating with seed: "troy, monts, montuori, montville, monty,"
# troy, monts, montuori, montville, monty, monz, mons, mont, monter, montler, montonigl, monpsocka, monsue, monta, montole, montley, montn, monton, mont, montock, monta, montalka, montala, montacana, montazo, montarella, montascota, montalanne, montenanda, montenda, monter, monteal, monteart, montell, montellis, montleom, honun, monworther, mony, monz, movalsy, movell, movezle, mowbyr, mowcet, mowett, mowellelle, mowell, mowle, morell, mo
# 784/784 [==============================] - 79s 100ms/step - loss: 0.6634

# %% [markdown]
# ## Without Shuffling
# Without shuffling, training took 12 minutes and 41 seconds, which is pretty long considering the previous models we trained. The loss ended up being 0.6634 at the end of 10 epochs. The names seem to be heavily influenced by the seed used for predicting on, as each name generated started with the first few majority letters of the seed names. Some of the names seem 'human', while others are not. Also, sometimes the predictor predicts the same name repetatively.

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end_shuffle)
for _ in range(10):
    name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
    with io.open(name_path, encoding='utf-8') as f:
        shuffled = f.read().lower() # make it all lowercase 
        
    shuffled = shuffled.split()
    random.shuffle(shuffled)
    shuffled = ', '.join(shuffled)

    maxlen = 40
    step = 5
    sentences = []
    next_chars = []
    for i in range(0, len(shuffled) - maxlen, step):
        sentences.append(shuffled[i: i + maxlen])
        next_chars.append(shuffled[i + maxlen])
    print('nb sequences:', len(sentences))
    print(shuffled[:100])

    # Turn these sentances into one-hot encoded vectors
    ## For all words in the sentances, there is a one, else there is a zero in that index of the vector

    print('Vectorization...')
    shuffled_x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
    shuffled_y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            shuffled_x[i, t, char_indices[char]] = 1
        shuffled_y[i, char_indices[next_chars[i]]] = 1
    print('Done!')
    
    shuffle.fit(shuffled_x, shuffled_y,
          batch_size=128,
          epochs=1,
          callbacks=[print_callback])
# Out:
# nb sequences: 100350
# goodrum, freire, cola, huyser, ballmer, bylund, samp, wilmot, edmx, shieh, edythe, gumpert, durgin,
# Vectorization...
# Done!
# 784/784 [==============================] - ETA: 0s - loss: 2.1485
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "sim, ellert, svr, from, steckler, gwartn"
# sim, ellert, svr, from, steckler, gwartner, wtart, wartz, wartz, wartz, wartz, wartz, wartze, wartze, wartze, wartz, wartz, wartz, wartze, wartz, wartze, wartze, wartze, wartze, wartz, wartz, wartz, wartz, wartze, wartzel, wartz, wartz, wartz, wartz, wartze, wartzel, wartz, wartz, wartze, wartzel, wartz, wartz, wartz, wartz, wartzer, wartz, wartz, wartze, wartz, wartze, wartz, wartz, wartze, wartze, wartz, wartz, wartze, wartz, wartz, w
# ----- diversity: 0.4
# ----- Generating with seed: "sim, ellert, svr, from, steckler, gwartn"
# sim, ellert, svr, from, steckler, gwartner, stre, streg, stregle, stregle, stregle, stregley, streiman, strein, streinbrann, streinbrann, streinbrager, streisen, streiske, streisley, streisley, streister, streiter, streits, strenker, strenker, strenkel, strenland, strenley, strenley, strenk, strene, strenn, strensch, strent, strent, strenzer, strenthause, strenz, strober, streburn, strebel, streber, streber, streber, streber, strebert,
# ----- diversity: 0.5
# ----- Generating with seed: "sim, ellert, svr, from, steckler, gwartn"
# sim, ellert, svr, from, steckler, gwartner, wtartz, wartz, wartz, wartz, wartz, wartze, wartz, wartze, wartzer, wartzen, wartz, wartz, wartz, wartz, wartze, wartzing, wartz, wartz, wartz, wartzel, wartz, wartze, wartz, wartz, wartz, wartz, wartz, wartzler, wartzel, wartz, wartz, wartzel, wartz, wartz, wartz, wartz, wartz, wartz, wartzel, wartz, wartze, wartze, wartz, wartz, wartz, wartz, wartzman, wartz, wartze, wartzel, wartz, wartze,
# ----- diversity: 1.0
# ----- Generating with seed: "sim, ellert, svr, from, steckler, gwartn"
# sim, ellert, svr, from, steckler, gwartner, streyn, strodell, strombel, strombt, stromhier, stromer, strondy, stroy, strovell, strow, sporwell, sporz, sporz, sporw, sposco, spuc, spuchua, spucis, spuccek, spucki, spuck, spucker, spuckson, spudes, spuder, spud, spudtin, spud, spunce, spup, spupe, spuska, spuler, spurstian, spurrant, spurrok, spurworth, spuzhara, spury, spura, spusantio, spuserly, spuskow, spuska, sputinia, sputh, sputto,
# 784/784 [==============================] - 80s 102ms/step - loss: 2.1485
# nb sequences: 100350
# kass, wansley, baggs, akiyama, kincaid, cronk, wimbush, rosendahl, harsha, ruddock, stofko, stanifer
# Vectorization...
# Done!
# 784/784 [==============================] - ETA: 0s - loss: 1.9776
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "rilliant, panella, mora, hohenberger, ys"
# rilliant, panella, mora, hohenberger, ysank, monkard, monker, monker, monkey, monkey, monkey, monkley, monkol, monkowski, monlon, monn, monnard, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner, monner,
# ----- diversity: 0.4
# ----- Generating with seed: "rilliant, panella, mora, hohenberger, ys"
# rilliant, panella, mora, hohenberger, ys, mohner, mohr, mohrer, mohrin, mohrin, mohring, mohrin, mohrer, mohris, mohrs, mohrin, mohrin, mohrin, mohrin, mohrt, mohrney, mohrman, mohrmann, mohron, mohrmann, mohrney, mohr, mohr, mohran, mohrer, mohrer, mohrer, mohren, mohren, mohren, mohren, mohr, mohr, mohrt, mohrman, mohrmann, mohrney, mohr, mohrin, mohrin, mohrin, mohrs, mohrman, mohrmann, mohrmann, mohrney, morker, morkin, morkley, mor
# ----- diversity: 0.5
# ----- Generating with seed: "rilliant, panella, mora, hohenberger, ys"
# rilliant, panella, mora, hohenberger, yshlaney, hori, horie, horiene, horiman, horino, hork, horkowski, horl, horlard, horlas, horlata, horlaster, horlain, horlard, horland, horlander, horlander, horlen, horlene, horlenburg, horlenberg, horlenbrant, horler, hormand, hormann, hormann, hormand, hormann, hormann, hormann, hormandrey, hormann, hormann, hormann, hormann, hormann, hormann, hormann, hormann, hormanne, hormann, hormarn, hormann
# ----- diversity: 1.0
# ----- Generating with seed: "rilliant, panella, mora, hohenberger, ys"
# rilliant, panella, mora, hohenberger, ysanker, monkard, monkart, monkark, monker, monks, monkstik, monksol, monksco, monkskin, monkscoll, mono, monos, monro, moopley, mooplitz, moprow, mopolter, mopl, mopler, mopler, moplotne, moplyn, mopo, mop, mopas, mopbaka, mopciano, mopcerrym, moperlyn, hoophi, hoprile, hoorbouel, hoorbura, hore, horeari, horece, horeskanle, horeuk, horo, horock, horoja, horoho, horox, horough, horreter, hors, hors
# 784/784 [==============================] - 80s 102ms/step - loss: 1.9776
# nb sequences: 100350
# leamon, rafi, lilyan, taft, scheufler, stahley, jehle, arguello, moninger, marietta, grech, oller, s
# Vectorization...
# Done!
# 784/784 [==============================] - ETA: 0s - loss: 1.9296
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " soller, desjardin, turck, quiroz, adar,"
#  soller, desjardin, turck, quiroz, adar, dura, duralla, durand, durander, durander, duranders, durandera, durandero, durande, durande, durander, durander, durandera, durander, durand, durander, durander, durandera, durander, duranders, durand, durander, durander, duranders, durander, durander, duranders, durander, durander, duranders, durander, duranders, duranders, durandera, durande, durande, durander, durand, durander, durandera, dur
# ----- diversity: 0.4
# ----- Generating with seed: " soller, desjardin, turck, quiroz, adar,"
#  soller, desjardin, turck, quiroz, adar, ladras, ladrick, ladrick, ladrick, ladrick, ladrick, ladrick, ladron, ladrick, ladrin, ladrick, ladrick, ladris, ladris, ladrick, ladrin, ladriss, ladriss, ladrist, ladson, ladster, lacos, lacos, lacos, lacos, lacos, lacosco, lacos, lacot, lacoz, lacos, lacos, lacos, lacosia, lacos, lacosca, lacos, lacoz, lacos, lacoz, lacos, lacos, lacoz, lacoz, lacoz, lacoz, lacoz, lacoz, lacoz, lacoz, lacoz, l
# ----- diversity: 0.5
# ----- Generating with seed: " soller, desjardin, turck, quiroz, adar,"
#  soller, desjardin, turck, quiroz, adar, dura, durald, duran, durcaran, durdas, durdam, durder, dure, duria, durian, durick, durin, duringer, duringer, durington, durington, durone, durona, duror, durow, durow, dury, duryer, duryer, dury, durz, durzon, durzer, durzyn, durzyn, dury, duryer, duryer, duryer, durye, duryer, duryer, duryer, duryer, duryan, duryer, duryer, duryer, dury, dury, duryer, duryer, durya, duryer, duryen, duryer, dur
# ----- diversity: 1.0
# ----- Generating with seed: " soller, desjardin, turck, quiroz, adar,"
#  soller, desjardin, turck, quiroz, adar, durcunnelli, dure, durez, durald, durbain, durbery, durbya, durick, durey, durzer, dury, huruyer, hurtz, hurvell, hurak, hurwell, hurver, hurz, hurzyne, hurzig, hurzak, hurzen, hurzyn, huryni, huse, huseldow, huselich, huselli, husengauer, husengrie, husena, husenbach, husenderburg, husenbaug, husendach, husher, hushoy, hushoon, hush-will, hushman, hushemaus, hushmig, hushmain, hushner, hushman,
# 784/784 [==============================] - 79s 101ms/step - loss: 1.9296
# nb sequences: 100350
# mellisa, hilmer, frager, campanale, fayth, nunnally, wasley, viverette, beitler, willi, hsu, demiche
# Vectorization...
# Done!
# 783/784 [============================>.] - ETA: 0s - loss: 1.9068
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "assi, bieler, palese, clapper, robbin, b"
# assi, bieler, palese, clapper, robbin, balbron, calbrook, caldara, caldara, caldan, caldanio, caldania, caldania, caldania, caldania, caldanio, caldania, caldania, caldania, caldania, caldania, caldania, caldania, caldara, caldano, caldania, caldania, caldania, caldania, caldania, caldano, caldania, caldania, caldania, caldania, caldano, caldano, caldania, caldania, caldania, caldania, caldania, caldania, caldania, caldania, caldania, c
# ----- diversity: 0.4
# ----- Generating with seed: "assi, bieler, palese, clapper, robbin, b"
# assi, bieler, palese, clapper, robbin, brabina, krabita, krabitta, krabita, krabita, krabita, krabita, krabita, krabit, krabita, krabrist, krabring, krabson, krabrick, krabst, kraby, kraber, kraber, krabs, kraber, kabre, kabil, kabrin, kabrick, kabrick, kabrish, kabriss, kabrick, kabrick, kabrik, kabrik, kabrick, kabrik, kabriss, kabriss, kabrick, kabrick, kabriss, kabriss, kabriss, kabriss, kabrist, kabrist, kabrian, kabrin, kabriss, k
# ----- diversity: 0.5
# ----- Generating with seed: "assi, bieler, palese, clapper, robbin, b"
# assi, bieler, palese, clapper, robbin, brald, kraber, kraber, kraber, kraber, kraber, krabin, kabrin, kraber, krabin, kraber, kraber, krabit, kraber, krabley, krabin, kraber, krabin, krabin, kraber, kraber, krabin, kraber, kraber, kraber, kraber, krabley, kraby, kraber, kraber, kraber, krabel, kraber, krabes, krabin, krabin, krabis, kraber, kraber, kraber, krabie, krabin, krabin, krabin, kraber, krabey, krabin, krabley, krabin, krable,
# ----- diversity: 1.0
# ----- Generating with seed: "assi, bieler, palese, clapper, robbin, b"
# assi, bieler, palese, clapper, robbin, balbron, kabler, kablill, kabman, kader, kadita, kaditz, kadita, kadin, kadier, kaell, kaker, kales, kaldy, kalburs, kaldoli, kalder, kald, kalcik, kaldykar, kaldow, kalkow, kaldstee, kaldstrosh, kalmel, kalney, kanlenberg, kanlew, kamerki, kammara, kammara, kams, kamschel, kamsammand, kamsen, kamson, kamson, kamt, kamtse, kant, kameper, kaoper, kapers, kapf, kapf, kaki, kajifaki, kail, kailberg, k
# 784/784 [==============================] - 80s 101ms/step - loss: 1.9065
# nb sequences: 100350
# lory, peretz, sandusky, stutes, lyndsey, edmonda, peiser, freimuth, krahn, kollmann, cissy, lynds, s
# Vectorization...
# Done!
# 783/784 [============================>.] - ETA: 0s - loss: 1.8990
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "e, seim, petruzzi, ulm, bonsall, nathan,"
# e, seim, petruzzi, ulm, bonsall, nathan, math, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathard, mathar
# ----- diversity: 0.4
# ----- Generating with seed: "e, seim, petruzzi, ulm, bonsall, nathan,"
# e, seim, petruzzi, ulm, bonsall, nathan, math, nathard, mather, matherson, mathers, mathers, mathers, mathers, mathers, mathers, mathers, mathert, mathers, matherson, matherson, mathers, mathers, mathiro, mathiro, mathis, mathitta, mathson, mathon, mathon, mathran, mathrer, mathris, mathrook, mathrow, mathrick, mathrin, mathiro, mathirick, mathiro, mathiricz, mathimer, mathint, mathins, mathine, mathine, mathin, mathman, mathon, mathorn
# ----- diversity: 0.5
# ----- Generating with seed: "e, seim, petruzzi, ulm, bonsall, nathan,"
# e, seim, petruzzi, ulm, bonsall, nathan, mathon, mathmann, mathman, mathon, mathorn, mathrin, mathner, math, mather, mather, mather, matherson, matherson, mathers, master, masti, mastik, mastin, mastin, mastine, mastina, mastine, mastinek, mastin, mastis, mastik, mastis, mastis, mastin, mastina, mastina, mastina, mastince, mastine, mastini, mastina, mastine, mastine, mastinen, mastine, mastine, mastis, mastis, mastim, mastina, mastine,
# ----- diversity: 1.0
# ----- Generating with seed: "e, seim, petruzzi, ulm, bonsall, nathan,"
# e, seim, petruzzi, ulm, bonsall, nathan, matonna, maton, matorey, matryn, matry, matrowski, masuro, mayson, maso, masquint, mast, mathab, mathalle, mathaod, mathand, mathar, matiara, matica, matick, matico, matiborte, matick, matick, mati, matila, matiles, matk, matolt, matlan, matley, matlle, matlerly, matley, matman, matner, matong, matora, matyer, matz, matzon, matzrar, matz, matze, matzel, matzeth, matzner, matzsen, matzmea, matzne,
# 784/784 [==============================] - 79s 101ms/step - loss: 1.8989
# nb sequences: 100350
# bev, garringer, mirra, routt, loeffler, raven, demel, donato, eskelson, levick, fortman, furnas, kre
# Vectorization...
# Done!
# 783/784 [============================>.] - ETA: 0s - loss: 1.8826
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "n, oberman, denslow, treder, lesner, vid"
# n, oberman, denslow, treder, lesner, vider, perman, prene, prenell, prener, prener, preng, preng, prenger, preng, prenger, preng, prenger, prenger, prenger, prenhard, priephane, priephant, priephan, priepp, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priepp, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priepper, priep
# ----- diversity: 0.4
# ----- Generating with seed: "n, oberman, denslow, treder, lesner, vid"
# n, oberman, denslow, treder, lesner, vider, rever, revick, revin, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins, revins
# ----- diversity: 0.5
# ----- Generating with seed: "n, oberman, denslow, treder, lesner, vid"
# n, oberman, denslow, treder, lesner, vider, perm, pern, pernand, pernard, pernard, pernard, pernard, pernand, pernander, pernberg, pernard, pernard, pernell, perner, perper, perpita, perporti, perrault, perrard, perrard, perrard, perrer, perri, perries, perring, perrington, perringer, perring, perron, perrow, perrow, perry, perry, perry, perrya, perryer, perris, perry, perry, perry, perryer, perryer, perry, perry, perry, perry, perry, p
# ----- diversity: 1.0
# ----- Generating with seed: "n, oberman, denslow, treder, lesner, vid"
# n, oberman, denslow, treder, lesner, vids, lespes, lesrel, less, lessadi, lessel, lesselman, lesser, lessi, lessing, lessing, lessing, lessing, lessling, lesslyn, lesson, lessly, lesson, lesson, lestley, lessnots, lesslund, lesshi, lessini, lessing, lessin, lessing, lessmars, lessler, lesslin, lesslinn, lesson, lesson, lesta, lesver, letschey, lesver, leswell, lespha, leswe, leschart, lescord, lescinn, lescosi, lescos, lescos, lesby, le
# 784/784 [==============================] - 80s 102ms/step - loss: 1.8828
# nb sequences: 100350
# faso, sichao, emigh, resler, bibbye, oakley, sanderfer, hatty, scholes, sanker, aydelotte, digiorgio
# Vectorization...
# Done!
# 783/784 [============================>.] - ETA: 0s - loss: 1.8763
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "acy, smee, martinec, ingalsbe, tool, wie"
# acy, smee, martinec, ingalsbe, tool, wienk, senker, senkley, senkley, senkoff, senkowski, senkstein, senkowski, senkow, senkstein, senkowski, senkowski, senkowski, senler, senley, senley, senlik, senlo, senn, sennard, senner, senner, senner, senner, senner, senner, senney, sennin, senning, senning, senninger, senning, sennings, senning, senning, sennings, senning, senninger, sennon, senns, senns, senns, sennstein, sennos, sennow, sennow
# ----- diversity: 0.4
# ----- Generating with seed: "acy, smee, martinec, ingalsbe, tool, wie"
# acy, smee, martinec, ingalsbe, tool, wiella, seine, seinhardt, seiner, seinock, seino, seinra, seinre, seins, seins, seins, seins, seins, seins, seins, seins, seins, seinser, seins, seins, seins, seins, seins, seins, seins, seins, seins, seins, seins, seins, seins, seins, seis, seit, seiter, seits, seitz, seetzer, seetzer, seetzer, seetz, seetzer, seever, sefers, seffer, seffer, sefford, seff, seger, segh, sehl, sehler, sehler, sehler,
# ----- diversity: 0.5
# ----- Generating with seed: "acy, smee, martinec, ingalsbe, tool, wie"
# acy, smee, martinec, ingalsbe, tool, wielland, seine, seine, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiner, seiners, seiner, seiner, seiney, seiner, seines, seiner, seiner, seiney, seiner, seiney, seiner, seines, seiner, seinhard, seinhardt, seinhardt, seinick, seinke, sein, seinberg, seinberg, seiner, seiner, seiner, seiner, seiner, seiner,
# ----- diversity: 1.0
# ----- Generating with seed: "acy, smee, martinec, ingalsbe, tool, wie"
# acy, smee, martinec, ingalsbe, tool, wieralli, shiesa, shil, shilli, shillig, shillman, shilmer, shilmeth, shilpen, shilper, shilrood, shillos, shilly, shilly, shilyha, shilyna, shilzon, shims, shimoos, shimiton, shimrook, shimley, shimliff, shilmigh, shino, shirols, shirrah, shirre, shirn, shirtel, shirterson, shirzer, shitza, shitzer, shi, shiafner, shiam, shibre, shibles, shibridge, shidbley, shidel, shieden, shiewlandiel, shiesland,
# 784/784 [==============================] - 80s 102ms/step - loss: 1.8762
# nb sequences: 100350
# quyen, tydings, pangle, ciesielski, vanderheide, steever, dosh, jaskowiak, silberg, aderhold, enke,
# Vectorization...
# Done!
# 783/784 [============================>.] - ETA: 0s - loss: 1.8720
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "e, swandi, summerfield, hopping, novitsk"
# e, swandi, summerfield, hopping, novitski, motmitz, moto, motz, motz, motzel, motzel, motzer, motza, motza, motze, motzel, moz, mozalco, mozali, mozella, mozella, mozalie, mozella, mozello, mozelle, mozella, mozello, mozello, mozella, mozelle, mozelle, mozelle, mozelle, mozelle, mozella, mozelle, mozelle, mozelle, mozelle, mozella, mozelle, mozella, mozelle, mozelle, mozelle, mozelle, mozelles, mozello, mozello, mozello, mozello, mozell
# ----- diversity: 0.4
# ----- Generating with seed: "e, swandi, summerfield, hopping, novitsk"
# e, swandi, summerfield, hopping, novitski, hovitz, hovitz, hovland, hovlon, hovlon, hovon, hovor, hovos, hovos, hov, hova, hova, hovak, hovack, hovack, hovack, hovack, hovack, hovack, hovacker, hovacker, hovacker, hovack, hovack, hovack, hovack, hovack, hovack, hovack, hovack, hovabich, hovack, hovak, hovack, hovabette, hovack, hovack, hovack, hovack, hovack, hovack, hovack, hovack, hovack, hovack, hovack, hovack, hovak, hovack, howal,
# ----- diversity: 0.5
# ----- Generating with seed: "e, swandi, summerfield, hopping, novitsk"
# e, swandi, summerfield, hopping, novitski, motmitz, motmon, moto, moton, motrins, motrow, motry, motry, motron, mort, mortald, mortan, mortann, mortanne, mortann, mortanne, mortannelle, mortanney, mortannes, mortanney, mortanes, mortanne, mortannelle, mortann, mortanne, mortannella, mortanney, mortani, mortanney, mortanney, mortannell, mortannell, mortando, mortane, mortane, mortanne, mortane, mortannella, mortando, mortane, mortane, mo
# ----- diversity: 1.0
# ----- Generating with seed: "e, swandi, summerfield, hopping, novitsk"
# e, swandi, summerfield, hopping, novitski, muckrow, nucus, nuce, nudens, nuee, nueyews, nuel, nuels, nuetleffer, nuemg, nufins, nugl, nugp, nugke, nugren, nugnish, nugroth, nugun, nugge, nugone, nuger, nuger, nuger, nuger, nuger, nug-fiann, nugk, nugt, nugstein, nugus, nug, nugon, nuguno, nuggen, nugwill, nug, nuge, nuga, nugan, nug, nuge, nugols, nugse, nugl, nugott, nugoige, nugm, nugard, nugough, nugque, nugor, nugona, nugare, nugman
# 784/784 [==============================] - 78s 99ms/step - loss: 1.8719
# nb sequences: 100350
# vanderhorst, rahrig, stigall, hermien, levi, hesper, profitt, karasek, deherrera, palombo, ward, don
# Vectorization...
# Done!
# 784/784 [==============================] - ETA: 0s - loss: 1.8656
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "orno, buerkle, minnnie, warning, ortez, "
# orno, buerkle, minnnie, warning, ortez, raster, rastick, rastik, rastis, rastiz, rastis, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin, rastin,
# ----- diversity: 0.4
# ----- Generating with seed: "orno, buerkle, minnnie, warning, ortez, "
# orno, buerkle, minnnie, warning, ortez, rastel, rastel, rasen, rasendare, rasenco, rasene, rasent, rasent, rasent, rasent, rasent, rasens, rasens, rasent, rasent, rasent, rasens, rasent, rasent, rasent, rasentine, rasentine, rasentine, rasentine, rasentie, raser, rases, rasett, rasetta, rasey, rasfield, rasg, rasha, rashane, rash, rasher, rasher, rashing, rashin, rashin, rashin, rashner, rashner, rashring, rashring, rashring, rashrin, r
# ----- diversity: 0.5
# ----- Generating with seed: "orno, buerkle, minnnie, warning, ortez, "
# orno, buerkle, minnnie, warning, ortez, rartin, rartner, ras, rasas, rasamire, rasana, rasana, rasane, rasas, rasbrome, rasbrowski, rasbrowski, rasbrowski, rasburg, rasburg, rasburg, rasber, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasberg, rasbin, rasbo, rasbis, rasbians, rasbina, rasbita, rasbill, rasken, rasler, raslon, rasmon, rasm
# ----- diversity: 1.0
# ----- Generating with seed: "orno, buerkle, minnnie, warning, ortez, "
# orno, buerkle, minnnie, warning, ortez, rashager, rashe, rashkor, rashki, rashke, rashli, rasron, rasoca, rasola, rasomard, rasory, rason, rasora, rasow, rasovas, rasotrey, rasomp, rasote, raspars, rasscon, rassburg, rassa, rasser, rassinger, rassone, rassow, rast, raste, raster, raster, raster, rastro, rastrdf, rasrnay, rass, rasser, rassrt, rasso, rassoc, rassons, rasson, rassow, rast, rastek, raster, rasver, rasel, rasella, rasen, ra
# 784/784 [==============================] - 80s 102ms/step - loss: 1.8656
# nb sequences: 100350
# feldstein, higley, skewes, mccready, amandip, fanelli, dinicola, hughett, crane, klute, allday, caia
# Vectorization...
# Done!
# 784/784 [==============================] - ETA: 0s - loss: 1.8541
# ----- Generating text_temp after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "un, timbrook, hoffart, larena, dortch, g"
# un, timbrook, hoffart, larena, dortch, gorgus, dorgson, dorin, doring, doring, doring, doring, doring, doring, doring, doring, doring, doring, doring, doring, doringer, dorings, doring, doring, doring, doring, doring, doring, doring, doring, doring, doring, doring, doringer, dorings, dorings, dorings, doring, dorings, doring, doring, dorings, dorington, dorington, doring, dorington, dorings, doring, doring, doring, doring, doring, dorin
# ----- diversity: 0.4
# ----- Generating with seed: "un, timbrook, hoffart, larena, dortch, g"
# un, timbrook, hoffart, larena, dortch, gorgutt, dortade, dortan, dortanne, dortennell, dortens, dortens, dortens, dortens, dortens, dorter, dorter, dorter, dortick, dorton, dortner, dortner, dortner, dortner, dortner, dortner, dortner, dortner, dortnney, dortne, dortner, dorts, dorther, dorth, dortick, dorton, dortron, dort, dorta, dortall, dortall, dortall, dortas, dortan, dortanne, dorter, dorther, dortin, dortin, dortin, dortin, dort
# ----- diversity: 0.5
# ----- Generating with seed: "un, timbrook, hoffart, larena, dortch, g"
# un, timbrook, hoffart, larena, dortch, gore, dorella, dorella, dorell, horen, horendord, horenner, horenke, horender, horenchann, horenhaunt, hores, horesta, horett, horett, horette, horett, horette, horette, horette, horethe, horez, horfa, horford, horford, horford, horfin, horford, horford, horford, horford, horforth, horfey, horfin, horfin, horfin, horford, horford, horfmann, horford, horffer, horffer, horffield, horfin, horffield, h
# ----- diversity: 1.0
# ----- Generating with seed: "un, timbrook, hoffart, larena, dortch, g"
# un, timbrook, hoffart, larena, dortch, gordwold, gordvell, gordy, horder, hordels, hordhers, hordies, hordin, hordine, hordins, hordinski, hordings, hordnie, hordor, hords, hordwell, hordrow, hordy, horfeld, horfen, horffen, horffelter, horfin, hori, horide, horine, horins, horinia, horoner, horohar, horomoy, horoul, horow, horsch, horst, horstik, horssez, horst, horsterger, horsteck, horster, horstedouc, horsteau, horseuch, horsest, ho
# 784/784 [==============================] - 78s 100ms/step - loss: 1.8541

# %% [markdown]
# ## With Shuffling
# When shuffling the names, the predictions didn't seem any better. The loss was much higher (at 1.8541) after 10 epochs. It took 13 minutes and 41 seconds, which was only a minute than without shuffling, and probably due to the way I was reading in the data each time, when I could have just re-shuffled.
